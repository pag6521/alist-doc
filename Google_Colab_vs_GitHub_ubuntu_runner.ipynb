# %% [markdown]
# <a href="https://colab.research.google.com/github/pag6521/alist-doc/blob/main/Google_Colab_vs_GitHub_ubuntu_runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://github.com/groda/big_data/blob/master/README.md"><div><img src="https://github.com/groda/big_data/blob/master/logo_bdb.png?raw=true" align=right width="90" alt="Logo Big Data for Beginners"></div></a>
# # Google Colab vs. GitHub Ubuntu Runner

# %% [markdown]
#
#
# I've noticed that the Big Data notebooks in the BDb repo run quite fast when [being tested by GitHub actions](https://github.com/groda/big_data/actions/workflows/run-notebooks.yml) compared to their runtimes on Google Colaboratory. You can find some timings in: [action_log.txt](https://github.com/groda/big_data/blob/367429dca1faeefc7c2d2dbfda023609a683c055/action_log.txt).
#
# So I compared the standard Google Colab virtual machine with GitHub's "ubuntu:latest" (**\***) runner and found out that not only the GitHub runner has $15$GB RAM ($3$GB more than Google Colab) but it also has double the amount of virtual CPU's ($4$ versus the $2$ of Google Colab).
#
# (**\***) As of December 2024, GitHub's "ubuntu-latest" image [is soon going to be replaced by "ubuntu-24.04"](https://github.com/actions/runner-images/issues/10636) (currently it's 22.04) so I'll need to substitute "ubuntu-22.04" to "ubuntu-latest" in GitHub since Colab is currently using "ubuntu-22.04".
#
# Below is a comparison table.

# %% [markdown]
# <table style="border: 1px solid black;vertical-align: top;">
# <tr>
# <th>
# <th>Google Colab
# <th>GitHub ubuntu runner
# <tr>
# <td><pre>free -h</pre>
# <td>
# <pre>               total        used        free      shared  buff/cache   available
# Mem:            12Gi       827Mi       7.1Gi       1.0Mi       4.7Gi        11Gi
# Swap:             0B          0B          0B
# </pre>
#  <td>
# <pre>
#                total        used        free      shared  buff/cache   available
# Mem:            15Gi       683Mi        13Gi        23Mi       1.0Gi        14Gi
# Swap:          4.0Gi          0B       4.0Gi
# </pre>
# <tr>
# <tr>
# <td>
# <pre>lscpu</pre>
# <td>
# <pre>
# Architecture:             x86_64
#   CPU op-mode(s):         32-bit, 64-bit
#   Address sizes:          46 bits physical, 48 bits virtual
#   Byte Order:             Little Endian
# CPU(s):                   2
#   On-line CPU(s) list:    0,1
# Vendor ID:                GenuineIntel
#   Model name:             Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:           6
#     Model:                79
#     Thread(s) per core:   2
#     Core(s) per socket:   1
#     Socket(s):            1
#     Stepping:             0
#     BogoMIPS:             4399.99
#     Flags:                fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 cl
#                           flush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc re
#                           p_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3
#                            fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                            hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp
#                           fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx sm
#                           ap xsaveopt arat md_clear arch_capabilities
# Virtualization features:
#   Hypervisor vendor:      KVM
#   Virtualization type:    full
# Caches (sum of all):
#   L1d:                    32 KiB (1 instance)
#   L1i:                    32 KiB (1 instance)
#   L2:                     256 KiB (1 instance)
#   L3:                     55 MiB (1 instance)
# NUMA:
#   NUMA node(s):           1
#   NUMA node0 CPU(s):      0,1
# Vulnerabilities:
#   Gather data sampling:   Not affected
#   Itlb multihit:          Not affected
#   L1tf:                   Mitigation; PTE Inversion
#   Mds:                    Vulnerable; SMT Host state unknown
#   Meltdown:               Vulnerable
#   Mmio stale data:        Vulnerable
#   Reg file data sampling: Not affected
#   Retbleed:               Vulnerable
#   Spec rstack overflow:   Not affected
#   Spec store bypass:      Vulnerable
#   Spectre v1:             Vulnerable: __user pointer sanitization and usercopy barriers only; no swa
#                           pgs barriers
#   Spectre v2:             Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-eIBRS: Not affected; BH
#                           I: Vulnerable (Syscall hardening enabled)
#   Srbds:                  Not affected
#   Tsx async abort:        Vulnerable
#   </pre>
# <td>
# <pre>
# Architecture:                       x86_64
# CPU op-mode(s):                     32-bit, 64-bit
# Address sizes:                      48 bits physical, 48 bits virtual
# Byte Order:                         Little Endian
# CPU(s):                             4
# On-line CPU(s) list:                0-3
# Vendor ID:                          AuthenticAMD
# Model name:                         AMD EPYC 7763 64-Core Processor
# CPU family:                         25
# Model:                              1
# Thread(s) per core:                 2
# Core(s) per socket:                 2
# Socket(s):                          1
# Stepping:                           1
# BogoMIPS:                           4890.85
# Flags:                              fpu vme de pse tsc msr pae mce cx8 apic sep
#                                     mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext
#                                     fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl tsc_reliable nonstop_tsc
#                                     cpuid extd_apicid aperfmperf pni pclmulqdq
#                                     ssse3 fma cx16 pcid sse4_1 sse4_2
#                                     movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy svm
#                                     cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext invpcid_single
#                                     vmmcall fsgsbase bmi1 avx2 smep bmi2 erms
#                                     invpcid rdseed adx smap clflushopt
#                                     clwb sha_ni xsaveopt xsavec xgetbv1 xsaves clzero xsaveerptr rdpru arat npt
#                                     nrip_save tsc_scale vmcb_clean flushbyasid decodeassists pausefilter
#                                     pfthreshold v_vmsave_vmload umip vaes vpclmulqdq rdpid fsrm
# Virtualization:                     AMD-V
# Hypervisor vendor:                  Microsoft
# Virtualization type:                full
# L1d cache:                          64 KiB (2 instances)
# L1i cache:                          64 KiB (2 instances)
# L2 cache:                           1 MiB (2 instances)
# L3 cache:                           32 MiB (1 instance)
# NUMA node(s):                       1
# NUMA node0 CPU(s):                  0-3
# Vulnerability Gather data sampling: Not affected
# Vulnerability Itlb multihit:        Not affected
# Vulnerability L1tf:                 Not affected
# Vulnerability Mds:                  Not affected
# Vulnerability Meltdown:             Not affected
# Vulnerability Mmio stale data:      Not affected
# Vulnerability Retbleed:             Not affected
# Vulnerability Spec rstack overflow: Vulnerable: Safe RET, no microcode
# Vulnerability Spec store bypass:    Vulnerable
# Vulnerability Spectre v1:           Mitigation; usercopy/swapgs barriers and __user pointer sanitization
# Vulnerability Spectre v2:           Mitigation; Retpolines; STIBP disabled;
#                                     RSB filling; PBRSB-eIBRS Not affected;
#                                     BHI Not affected
# Vulnerability Srbds:                Not affected
# Vulnerability Tsx async abort:      Not affected
# </pre>
# </table>

# %% [markdown]
# ## Data collection on Colab

# %% [markdown]
# Get information on the processing units (CPUs) with [`lscpu`](https://unix.stackexchange.com/questions/468766/understanding-output-of-lscpu):

# %%
# !lscpu
# Out:
# Architecture:             x86_64
#   CPU op-mode(s):         32-bit, 64-bit
#   Address sizes:          46 bits physical, 48 bits virtual
#   Byte Order:             Little Endian
# CPU(s):                   2
#   On-line CPU(s) list:    0,1
# Vendor ID:                GenuineIntel
#   Model name:             Intel(R) Xeon(R) CPU @ 2.00GHz
#     CPU family:           6
#     Model:                85
#     Thread(s) per core:   2
#     Core(s) per socket:   1
#     Socket(s):            1
#     Stepping:             3
#     BogoMIPS:             4000.45
#     Flags:                fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge m
#                           ca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht sysc
#                           all nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xt
#                           opology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq
#                            ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt
# ...

# %% [markdown]
# Show the amount of total/free/used memory in human-readable format (option `-h`):

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       777Mi       8.9Gi       1.0Mi       3.0Gi        11Gi
# Swap:             0B          0B          0B

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.4 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.4 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %% [markdown]
# ## Data collection on GitHub
#
# In order to collect information on the GitHub runner I created an [_action_](https://docs.github.com/en/actions/writing-workflows/quickstart) defined in the YAML file [get_info_on_runner.yml](https://github.com/groda/big_data/blob/master/.github/workflows/get_info_on_runner.yml):
#
# ```bash
# name: Get info on runner
# run-name: Runner info
# on:
#   # needs to be started manually (by clicking on it)
#   workflow_dispatch:
# jobs:
#   Runner-Info-RAM-CPU:
#     runs-on: ubuntu-latest
#     steps:
#       - run: lscpu
#       - run: free -h
#       - run: cat /etc/os-release
#       - run: echo "🍏 This job's status is ${{ job.status }}."
# ```

# %% [markdown]
# **Status:** Dec. 02, 2024
#
# (these things change over time)

# %% [markdown]
# # Task
# 分析並優化歸納整理檔案 "/content/nba_logreg1.csv" 的資料。

# %% [markdown]
# ## 載入資料
#
# ### Subtask:
# 使用 pandas 讀取 `/content/nba_logreg1.csv` 檔案到 DataFrame 中。

# %% [markdown]
# **Reasoning**:
# Import the pandas library and read the CSV file into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('/content/nba_logreg1.csv')

# %% [markdown]
# **Reasoning**:
# Display the first few rows of the DataFrame to verify the data has been loaded correctly.

# %%
display(df.head())
# Out:
#               Name  GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA   3P%  ...  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  ...
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5  ...
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4  ...
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6  ...
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0  ...
#
#    FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3            0
# 1  3.4  76.5   0.5   2.0  2.4  3.7  1.1  0.5  1.6            0
# 2  1.3  67.0   0.5   1.7  2.2  1.0  0.5  0.3  1.0            0
# 3  1.3  68.9   1.0   0.9  1.9  0.8  0.6  0.1  1.0            1
# 4  1.9  67.4   1.0   1.5  2.5  0.3  0.3  0.4  0.8            1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 資料概覽
#
# ### Subtask:
# 顯示 DataFrame 的前幾行、列名、資料類型以及缺失值資訊，以初步了解資料結構和內容。

# %% [markdown]
# **Reasoning**:
# Display the head, column names, data types, and non-null counts of the DataFrame to understand its structure and content.

# %%
display(df.head())
display(df.columns)
display(df.info())
# Out:
#               Name  GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA   3P%  ...  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  ...
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5  ...
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4  ...
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6  ...
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0  ...
#
#    FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3            0
# 1  3.4  76.5   0.5   2.0  2.4  3.7  1.1  0.5  1.6            0
# 2  1.3  67.0   0.5   1.7  2.2  1.0  0.5  0.3  1.0            0
# 3  1.3  68.9   1.0   0.9  1.9  0.8  0.6  0.1  1.0            1
# 4  1.9  67.4   1.0   1.5  2.5  0.3  0.3  0.4  0.8            1
#
# [5 rows x 21 columns]
# Index(['Name', 'GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3P Made', '3PA',
# ...

# %% [markdown]
# ## 描述性統計
#
# ### Subtask:
# 計算數值型欄位的描述性統計量 (如均值、標準差、最小值、最大值等)，並顯示類別型欄位的計數。

# %% [markdown]
# **Reasoning**:
# Calculate and display descriptive statistics for numerical columns and value counts for categorical columns as per the instructions.

# %%
display(df.describe())
display(df['Name'].value_counts())
display(df['TARGET_5Yrs'].value_counts())
# Out:
#                 GP          MIN          PTS          FGM          FGA  \
# count  1340.000000  1340.000000  1340.000000  1340.000000  1340.000000
# mean     60.414179    17.624627     6.801493     2.629104     5.885299
# std      17.433992     8.307964     4.357545     1.683555     3.593488
# min      11.000000     3.100000     0.700000     0.300000     0.800000
# 25%      47.000000    10.875000     3.700000     1.400000     3.300000
# 50%      63.000000    16.100000     5.550000     2.100000     4.800000
# 75%      77.000000    22.900000     8.800000     3.400000     7.500000
# max      82.000000    40.900000    28.200000    10.200000    19.800000
#
#                FG%      3P Made          3PA          3P%          FTM  \
# count  1340.000000  1340.000000  1340.000000  1329.000000  1340.000000
# mean     44.169403     0.247612     0.779179    19.308126     1.297687
# std       6.137679     0.383688     1.061847    16.022916     0.987246
# ...

# %% [markdown]
# ## 資料清理
#
# ### Subtask:
# 根據概覽和統計結果，處理缺失值、異常值或重複項。

# %% [markdown]
# **Reasoning**:
# Check for and remove duplicate rows, then handle missing values in the '3P%' column by dropping rows with missing values, and finally display the number of remaining missing values to confirm the action.

# %%
df.drop_duplicates(inplace=True)
df.dropna(subset=['3P%'], inplace=True)
display(df.isnull().sum())
# Out:
# Name           0
# GP             0
# MIN            0
# PTS            0
# FGM            0
# FGA            0
# FG%            0
# 3P Made        0
# 3PA            0
# 3P%            0
# FTM            0
# FTA            0
# FT%            0
# OREB           0
# DREB           0
# REB            0
# AST            0
# STL            0
# BLK            0
# TOV            0
# TARGET_5Yrs    0
# dtype: int64

# %% [markdown]
# **Reasoning**:
# Check for outliers in numerical columns using descriptive statistics and decide if any treatment is necessary based on extreme values.

# %%
display(df.describe())
# Out:
#                 GP          MIN          PTS          FGM          FGA  \
# count  1318.000000  1318.000000  1318.000000  1318.000000  1318.000000
# mean     60.402124    17.654249     6.821017     2.635357     5.900910
# std      17.457767     8.340224     4.368868     1.687763     3.600133
# min      11.000000     3.100000     0.700000     0.300000     0.800000
# 25%      47.000000    10.825000     3.700000     1.400000     3.300000
# 50%      63.000000    16.100000     5.600000     2.100000     4.800000
# 75%      77.000000    22.975000     8.800000     3.400000     7.500000
# max      82.000000    40.900000    28.200000    10.200000    19.800000
#
#                FG%      3P Made          3PA          3P%          FTM  \
# count  1318.000000  1318.000000  1318.000000  1318.000000  1318.000000
# mean     44.138998     0.249621     0.784598    19.322989     1.302731
# std       6.116819     0.385397     1.065365    16.045404     0.989255
# ...

# %% [markdown]
# ## 資料整理與分析
#
# ### Subtask:
# 根據您的具體需求，進行資料分組、聚合、轉換或執行更深入的分析（例如相關性分析、分佈分析等）。

# %% [markdown]
# **Reasoning**:
# Calculate and display the correlation matrix for numerical columns, calculate and display correlations with 'TARGET_5Yrs', calculate and display the distribution of 'TARGET_5Yrs', and calculate and display the mean of selected numerical columns grouped by 'TARGET_5Yrs'.

# %%
display(df.corr(numeric_only=True))

display(df.corr(numeric_only=True)['TARGET_5Yrs'].sort_values(ascending=False))

display(df['TARGET_5Yrs'].value_counts())

selected_cols = ['PTS', 'AST', 'REB']
display(df.groupby('TARGET_5Yrs')[selected_cols].mean())
# Out:
#                    GP       MIN       PTS       FGM       FGA       FG%  \
# GP           1.000000  0.593356  0.541334  0.545647  0.521358  0.293458
# MIN          0.593356  1.000000  0.911624  0.902738  0.910329  0.207097
# PTS          0.541334  0.911624  1.000000  0.990867  0.980041  0.259893
# FGM          0.545647  0.902738  0.990867  1.000000  0.980315  0.295872
# FGA          0.521358  0.910329  0.980041  0.980315  1.000000  0.135322
# FG%          0.293458  0.207097  0.259893  0.295872  0.135322  1.000000
# 3P Made      0.111331  0.391862  0.348517  0.290943  0.391395 -0.289375
# 3PA          0.103249  0.405573  0.358777  0.301147  0.414618 -0.345068
# 3P%          0.041476  0.168600  0.154641  0.122794  0.199887 -0.328295
# FTM          0.483782  0.791200  0.896424  0.848348  0.827497  0.249928
# FTA          0.481036  0.779971  0.881036  0.840949  0.806829  0.303066
# FT%          0.193759  0.236707  0.254899  0.219750  0.265184 -0.153853
# ...

# %% [markdown]
# ## 結果呈現
#
# ### Subtask:
# 以清晰易懂的方式呈現分析結果，例如使用表格、圖表或文字說明。

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 1340 entries and 21 columns, including player statistics and a target variable `TARGET_5Yrs`.
# *   The `TARGET_5Yrs` column indicates whether a player stayed in the league for 5 years or more (1) or not (0).
# *   The `3P%` column was identified as having 11 missing values.
# *   Duplicate rows were successfully removed from the dataset.
# *   Rows with missing values in the `3P%` column were removed, resulting in a clean dataset for analysis.
# *   Based on descriptive statistics, no extreme outliers were identified in the numerical columns.
# *   `GP` (Games Played) showed the strongest positive correlation with `TARGET_5Yrs` (approximately 0.40).
# *   Other statistics like MIN, FGM, PTS, REB, FTA, FTM, OREB, FGA, DREB, and TOV also had positive correlations with `TARGET_5Yrs`.
# *   Players who stayed for 5 years or more (`TARGET_5Yrs` = 1) had higher average PTS, AST, and REB compared to those who did not (`TARGET_5Yrs` = 0).
#
# ### Insights or Next Steps
#
# *   Consider building a predictive model using features with strong correlations to `TARGET_5Yrs` (like GP, MIN, PTS, AST, REB) to predict player longevity.
# *   Explore the distribution of key features for each `TARGET_5Yrs` group using visualizations (e.g., histograms, box plots) to gain further insights into performance differences.
